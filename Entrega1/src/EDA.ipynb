# %% [markdown]
# #EDA

# %%
pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ###Datos caminar girar

# %%
import pandas as pd

df = pd.read_csv('/content/datosCaminarGirar.csv', delimiter=';')

print(df.head())
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     2.85       0.489825      -0.041248      -0.328458       0.546514
# 1     2.88       0.486441      -0.042775      -0.378111       0.550610
# 2     2.92       0.486839      -0.030136      -0.402729       0.550282
# 3     2.95       0.487542      -0.029593      -0.385953       0.548678
# 4     2.98       0.486612      -0.030032      -0.404531       0.548264
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.063067      -0.251517       0.428927       0.060231      -0.139171
# 1       0.063253      -0.213956       0.425805       0.060219      -0.176355
# 2       0.063636      -0.235838       0.425812       0.062523      -0.189046
# 3       0.063829      -0.244406       0.425845       0.063156      -0.178923
# 4       0.064743      -0.232976       0.423856       0.063984      -0.196225
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# 0  ...             0.392612             0.462908            -0.171285
# 1  ...             0.366174             0.463003            -0.213933
# 2  ...             0.367848             0.463025            -0.230665
# 3  ...             0.383487             0.468249            -0.231986
# 4  ...             0.362847             0.467007            -0.220830
#
#    pie_izquierdo_prom_x  pie_izquierdo_prom_y  pie_izquierdo_prom_z  \
# 0              0.483011     0.979324201742808   0.11360432455937068
# 1              0.517239    0.9915915330251058   0.09624355022485058
# 2              0.508895    0.9893796046574911   0.08208702318370342
# 3              0.495109    0.9887617429097494   0.08259721985086799
# 4              0.501523     0.990654706954956   0.08507826249115169
#
#    pie_derecho_prom_x  pie_derecho_prom_y pie_derecho_prom_z    Etiqueta
# 0            0.511644  0.9892005125681559           0.161948  alejandose
# 1            0.479354  0.9816381931304932           0.138144  alejandose
# 2            0.491645  0.9876887996991476           0.118823  alejandose
# 3            0.498900  0.9901951352755228           0.120991  alejandose
# 4            0.495318  0.9941532015800476           0.117580  alejandose
#
# [5 rows x 44 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                1669 non-null   float64
#  1   landmark_10_x          1669 non-null   float64
#  2   landmark_10_y          1669 non-null   float64
#  3   landmark_10_z          1669 non-null   float64
#  4   landmark_11_x          1669 non-null   float64
#  5   landmark_11_y          1669 non-null   float64
#  6   landmark_11_z          1669 non-null   float64
#  7   landmark_12_x          1669 non-null   float64
#  8   landmark_12_y          1669 non-null   float64
#  9   landmark_12_z          1669 non-null   float64
#  10  landmark_13_x          1669 non-null   float64
#  11  landmark_13_y          1669 non-null   float64
#  12  landmark_13_z          1669 non-null   float64
#  13  landmark_14_x          1669 non-null   float64
#  14  landmark_14_y          1669 non-null   float64
#  15  landmark_14_z          1669 non-null   float64
#  16  landmark_23_x          1669 non-null   float64
#  17  landmark_23_y          1669 non-null   float64
#  18  landmark_23_z          1669 non-null   object
#  19  landmark_24_x          1669 non-null   float64
#  20  landmark_24_y          1669 non-null   float64
#  21  landmark_24_z          1669 non-null   object
#  22  landmark_25_x          1669 non-null   float64
#  23  landmark_25_y          1669 non-null   float64
#  24  landmark_25_z          1669 non-null   float64
#  25  landmark_26_x          1669 non-null   float64
#  26  landmark_26_y          1669 non-null   float64
#  27  landmark_26_z          1669 non-null   object
#  28  cara_prom_x            1669 non-null   float64
#  29  cara_prom_y            1669 non-null   float64
#  30  cara_prom_z            1669 non-null   float64
#  31  mano_izquierda_prom_x  1669 non-null   float64
#  32  mano_izquierda_prom_y  1669 non-null   float64
#  33  mano_izquierda_prom_z  1669 non-null   float64
#  34  mano_derecha_prom_x    1669 non-null   float64
#  35  mano_derecha_prom_y    1669 non-null   float64
#  36  mano_derecha_prom_z    1669 non-null   float64
#  37  pie_izquierdo_prom_x   1669 non-null   float64
#  38  pie_izquierdo_prom_y   1669 non-null   object
#  39  pie_izquierdo_prom_z   1669 non-null   object
#  40  pie_derecho_prom_x     1669 non-null   float64
#  41  pie_derecho_prom_y     1669 non-null   object
#  42  pie_derecho_prom_z     1669 non-null   float64
#  43  Etiqueta               1669 non-null   object
# dtypes: float64(37), object(7)
# memory usage: 573.8+ KB
# None

# %%
print(df.describe())
# Out:
#            segundo  landmark_10_x  landmark_10_y  landmark_10_z  \
# count  1669.000000    1669.000000    1669.000000    1669.000000
# mean     43.004518       0.471507       0.079475      -0.117400
# std      23.805149       0.056484       0.118133       0.182959
# min       2.850000       0.167719      -0.245117      -0.727034
# 25%      21.710000       0.453764       0.032756      -0.271389
# 50%      42.990000       0.477727       0.075448      -0.146410
# 75%      61.590000       0.499114       0.096074       0.037230
# max      82.460000       0.591965       0.549885       0.499232
#
#        landmark_11_x  landmark_11_y  landmark_11_z  landmark_12_x  \
# count    1669.000000    1669.000000    1669.000000    1669.000000
# mean        0.481818       0.155152      -0.100918       0.464252
# std         0.072749       0.089758       0.140927       0.070082
# min         0.163676      -0.146916      -0.628478       0.181368
# 25%         0.449098       0.132810      -0.172614       0.428082
# 50%         0.493716       0.161806      -0.110927       0.457074
# 75%         0.532886       0.182094      -0.009647       0.503654
# max         0.643921       0.540270       0.399771       0.657266
#
#        landmark_12_y  landmark_12_z  ...  cara_prom_z  mano_izquierda_prom_x  \
# count    1669.000000    1669.000000  ...  1669.000000            1669.000000
# mean        0.155041      -0.081780  ...    -0.130932               0.482300
# std         0.087273       0.140701  ...     0.179695               0.093127
# min        -0.124377      -0.490984  ...    -0.796380               0.152484
# 25%         0.129343      -0.155319  ...    -0.276956               0.418509
# 50%         0.160767      -0.094185  ...    -0.152408               0.489695
# 75%         0.179925       0.026714  ...     0.023016               0.562803
# max         0.523632       0.356853  ...     0.524748               0.756452
#
#        mano_izquierda_prom_y  mano_izquierda_prom_z  mano_derecha_prom_x  \
# count            1669.000000            1669.000000          1669.000000
# mean                0.465232              -0.104804             0.460534
# std                 0.034561               0.179634             0.094739
# min                 0.047981              -0.788892             0.174349
# 25%                 0.461782              -0.204585             0.393316
# 50%                 0.471795              -0.150538             0.447036
# 75%                 0.480103               0.040993             0.530966
# max                 0.567885               0.638083             0.759094
#
#        mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# count          1669.000000          1669.000000           1669.000000
# mean              0.460739            -0.084711              0.476270
# std               0.024501             0.199640              0.056959
# min               0.182615            -0.890948              0.120946
# 25%               0.454386            -0.210426              0.457225
# 50%               0.463302            -0.126775              0.483868
# 75%               0.471950             0.068462              0.510023
# max               0.548824             0.982795              0.602857
#
#        pie_derecho_prom_x  pie_derecho_prom_z
# count         1669.000000         1669.000000
# mean             0.473170            0.174894
# std              0.051694            0.160562
# min              0.153240           -0.216460
# 25%              0.450553            0.057283
# 50%              0.469840            0.147948
# 75%              0.504693            0.261180
# max              0.677886            0.993821
#
# [8 rows x 37 columns]

# %%
print(df.isnull().sum())
# Out:
# segundo                  0
# landmark_10_x            0
# landmark_10_y            0
# landmark_10_z            0
# landmark_11_x            0
# landmark_11_y            0
# landmark_11_z            0
# landmark_12_x            0
# landmark_12_y            0
# landmark_12_z            0
# landmark_13_x            0
# landmark_13_y            0
# landmark_13_z            0
# landmark_14_x            0
# landmark_14_y            0
# landmark_14_z            0
# landmark_23_x            0
# landmark_23_y            0
# landmark_23_z            0
# landmark_24_x            0
# landmark_24_y            0
# landmark_24_z            0
# landmark_25_x            0
# landmark_25_y            0
# landmark_25_z            0
# landmark_26_x            0
# landmark_26_y            0
# landmark_26_z            0
# cara_prom_x              0
# cara_prom_y              0
# cara_prom_z              0
# mano_izquierda_prom_x    0
# mano_izquierda_prom_y    0
# mano_izquierda_prom_z    0
# mano_derecha_prom_x      0
# mano_derecha_prom_y      0
# mano_derecha_prom_z      0
# pie_izquierdo_prom_x     0
# pie_izquierdo_prom_y     0
# pie_izquierdo_prom_z     0
# pie_derecho_prom_x       0
# pie_derecho_prom_y       0
# pie_derecho_prom_z       0
# Etiqueta                 0
# dtype: int64

# %%
for col in ['landmark_23_z', 'landmark_24_z', 'landmark_25_z', 'landmark_26_z',
            'pie_izquierdo_prom_y', 'pie_izquierdo_prom_z', 'pie_derecho_prom_y']:
    df[col] = pd.to_numeric(df[col], errors='coerce')


df['Etiqueta'] = df['Etiqueta'].astype('category')

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
# Estadísticas descriptivas solo para columnas numéricas
df.describe()
# Out:
#            segundo  landmark_10_x  landmark_10_y  landmark_10_z  \
# count  1669.000000    1669.000000    1669.000000    1669.000000
# mean     43.004518       0.471507       0.079475      -0.117400
# std      23.805149       0.056484       0.118133       0.182959
# min       2.850000       0.167719      -0.245117      -0.727034
# 25%      21.710000       0.453764       0.032756      -0.271389
# 50%      42.990000       0.477727       0.075448      -0.146410
# 75%      61.590000       0.499114       0.096074       0.037230
# max      82.460000       0.591965       0.549885       0.499232
#
#        landmark_11_x  landmark_11_y  landmark_11_z  landmark_12_x  \
# count    1669.000000    1669.000000    1669.000000    1669.000000
# mean        0.481818       0.155152      -0.100918       0.464252
# std         0.072749       0.089758       0.140927       0.070082
# min         0.163676      -0.146916      -0.628478       0.181368
# 25%         0.449098       0.132810      -0.172614       0.428082
# 50%         0.493716       0.161806      -0.110927       0.457074
# 75%         0.532886       0.182094      -0.009647       0.503654
# max         0.643921       0.540270       0.399771       0.657266
#
#        landmark_12_y  landmark_12_z  ...  mano_izquierda_prom_z  \
# count    1669.000000    1669.000000  ...            1669.000000
# mean        0.155041      -0.081780  ...              -0.104804
# std         0.087273       0.140701  ...               0.179634
# min        -0.124377      -0.490984  ...              -0.788892
# 25%         0.129343      -0.155319  ...              -0.204585
# 50%         0.160767      -0.094185  ...              -0.150538
# 75%         0.179925       0.026714  ...               0.040993
# max         0.523632       0.356853  ...               0.638083
#
#        mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# count          1669.000000          1669.000000          1669.000000
# mean              0.460534             0.460739            -0.084711
# std               0.094739             0.024501             0.199640
# min               0.174349             0.182615            -0.890948
# 25%               0.393316             0.454386            -0.210426
# 50%               0.447036             0.463302            -0.126775
# 75%               0.530966             0.471950             0.068462
# max               0.759094             0.548824             0.982795
#
#        pie_izquierdo_prom_x  pie_izquierdo_prom_y  pie_izquierdo_prom_z  \
# count           1669.000000           1669.000000           1669.000000
# mean               0.476270              0.805296              0.159570
# std                0.056959              0.256587              0.150045
# min                0.120946             -0.828366             -0.229406
# 25%                0.457225              0.849589              0.069608
# 50%                0.483868              0.879839              0.141898
# 75%                0.510023              0.906229              0.239614
# max                0.602857              0.999615              0.983560
#
#        pie_derecho_prom_x  pie_derecho_prom_y  pie_derecho_prom_z
# count         1669.000000         1669.000000         1669.000000
# mean             0.473170            0.805085            0.174894
# std              0.051694            0.257362            0.160562
# min              0.153240           -0.848322           -0.216460
# 25%              0.450553            0.857683            0.057283
# 50%              0.469840            0.877005            0.147948
# 75%              0.504693            0.903350            0.261180
# max              0.677886            0.999988            0.993821
#
# [8 rows x 43 columns]

# %%
df['Etiqueta'].value_counts()
# Out:
# Etiqueta
# girando        749
# acercandose    527
# alejandose     393
# Name: count, dtype: int64

# %%
sns.countplot(x='Etiqueta', data=df)
plt.title('Distribución de Etiquetas')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=30, figsize=(10, 8))
plt.show()

# %%
import seaborn as sns

# Calcular correlación entre columnas numéricas
corr = df.select_dtypes(include=['float64', 'int64']).corr()

# Hacer el heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='coolwarm')
plt.title('Mapa de calor de correlaciones')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['landmark_10_x'], df['landmark_10_y'], df['landmark_10_z'], c='blue', s=1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Distribución 3D de landmark_10')
plt.show()

# %%
# prompt: Quiero un grafico de dispersion normal

import matplotlib.pyplot as plt
# Crear un gráfico de dispersión para dos columnas numéricas
plt.figure(figsize=(8, 6))
sns.scatterplot(x='landmark_10_x', y='landmark_10_y', data=df, hue='Etiqueta') # Agrega la columna 'Etiqueta' para el color
plt.title('Gráfico de Dispersión de landmark_10_x vs landmark_10_y')
plt.xlabel('landmark_10_x')
plt.ylabel('landmark_10_y')
plt.show()

# %% [markdown]
# #Datos inclinación

# %%
df = pd.read_csv('/content/datosInclinacion.csv', delimiter=';')

print(df.head())
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     1.25       0.530809      -0.045359       0.078343       0.456630
# 1     1.28       0.531234      -0.036965       0.048784       0.456141
# 2     1.31       0.530883      -0.024750      -0.001660       0.455986
# 3     1.35       0.530804      -0.014716      -0.041836       0.455754
# 4     1.38       0.527659      -0.009068      -0.010881       0.452470
#
#    landmark_11_y         landmark_11_z  landmark_12_x        landmark_12_y  \
# 0       0.047371   -0.1008719950914383       0.587075  0.07925322651863098
# 1       0.047351  -0.12318199872970581       0.586207  0.07942180335521698
# 2       0.048198  -0.15151673555374146       0.583240  0.08088546991348267
# 3       0.049754   -0.1623842716217041       0.579504  0.08523789793252945
# 4       0.053088  -0.14955712854862213       0.576396  0.09074155986309052
#
#           landmark_12_z  ...  mano_derecha_prom_x  mano_derecha_prom_y  \
# 0  -0.05644937604665756  ...             0.620462             0.456614
# 1  -0.05771622806787491  ...             0.620277             0.457900
# 2  -0.08281366527080536  ...             0.620007             0.458060
# 3   -0.1073591336607933  ...             0.620041             0.458711
# 4  -0.09602884948253632  ...             0.620082             0.459773
#
#   mano_derecha_prom_z  pie_izquierdo_prom_x  pie_izquierdo_prom_y  \
# 0            0.089181              0.433880    0.9648909568786621
# 1            0.121594              0.431556    0.9523735642433167
# 2            0.086675              0.431861    0.9433445533116659
# 3            0.086292              0.432252    0.9348804553349813
# 4            0.086391              0.432515     0.930977980295817
#
#   pie_izquierdo_prom_z  pie_derecho_prom_x  pie_derecho_prom_y  \
# 0             0.210564            0.526131  0.9547601938247681
# 1             0.165617            0.526148  0.9563078681627909
# 2             0.163039            0.524672  0.9547800223032633
# 3             0.201002            0.518285  0.9562047521273295
# 4             0.216168            0.520432  0.9558969338734945
#
#   pie_derecho_prom_z  Etiqueta
# 0           0.294089  vertical
# 1           0.226265  vertical
# 2           0.226567  vertical
# 3           0.214087  vertical
# 4           0.186384  vertical
#
# [5 rows x 44 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1279 entries, 0 to 1278
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                1279 non-null   float64
#  1   landmark_10_x          1279 non-null   float64
#  2   landmark_10_y          1279 non-null   float64
#  3   landmark_10_z          1279 non-null   float64
#  4   landmark_11_x          1279 non-null   float64
#  5   landmark_11_y          1279 non-null   float64
#  6   landmark_11_z          1279 non-null   object
#  7   landmark_12_x          1279 non-null   float64
#  8   landmark_12_y          1279 non-null   object
#  9   landmark_12_z          1279 non-null   object
#  10  landmark_13_x          1279 non-null   float64
#  11  landmark_13_y          1279 non-null   float64
#  12  landmark_13_z          1279 non-null   object
#  13  landmark_14_x          1279 non-null   float64
#  14  landmark_14_y          1279 non-null   float64
#  15  landmark_14_z          1279 non-null   object
#  16  landmark_23_x          1279 non-null   float64
#  17  landmark_23_y          1279 non-null   float64
#  18  landmark_23_z          1279 non-null   object
#  19  landmark_24_x          1279 non-null   float64
#  20  landmark_24_y          1279 non-null   float64
#  21  landmark_24_z          1279 non-null   object
#  22  landmark_25_x          1279 non-null   float64
#  23  landmark_25_y          1279 non-null   float64
#  24  landmark_25_z          1279 non-null   float64
#  25  landmark_26_x          1279 non-null   float64
#  26  landmark_26_y          1279 non-null   float64
#  27  landmark_26_z          1279 non-null   float64
#  28  cara_prom_x            1279 non-null   float64
#  29  cara_prom_y            1279 non-null   object
#  30  cara_prom_z            1279 non-null   float64
#  31  mano_izquierda_prom_x  1279 non-null   float64
#  32  mano_izquierda_prom_y  1279 non-null   float64
#  33  mano_izquierda_prom_z  1279 non-null   object
#  34  mano_derecha_prom_x    1279 non-null   float64
#  35  mano_derecha_prom_y    1279 non-null   float64
#  36  mano_derecha_prom_z    1279 non-null   float64
#  37  pie_izquierdo_prom_x   1279 non-null   float64
#  38  pie_izquierdo_prom_y   1279 non-null   object
#  39  pie_izquierdo_prom_z   1279 non-null   float64
#  40  pie_derecho_prom_x     1279 non-null   float64
#  41  pie_derecho_prom_y     1279 non-null   object
#  42  pie_derecho_prom_z     1279 non-null   float64
#  43  Etiqueta               1279 non-null   object
# dtypes: float64(32), object(12)
# memory usage: 439.8+ KB
# None

# %%
print(df.describe())
# Out:
#            segundo  landmark_10_x  landmark_10_y  landmark_10_z  \
# count  1279.000000    1279.000000    1279.000000    1279.000000
# mean     22.790438       0.475848       0.075336      -0.082238
# std      12.455513       0.079091       0.056285       0.226325
# min       1.250000       0.330940      -0.187323      -0.613690
# 25%      12.015000       0.427392       0.048981      -0.281034
# 50%      22.790000       0.478018       0.070693      -0.195316
# 75%      33.560000       0.531562       0.104504       0.176308
# max      45.440000       0.628358       0.712694       0.278364
#
#        landmark_11_x  landmark_11_y  landmark_12_x  landmark_13_x  \
# count    1279.000000    1279.000000    1279.000000    1279.000000
# mean        0.475382       0.154698       0.460993       0.475504
# std         0.076046       0.052296       0.072009       0.082109
# min         0.314174      -0.085738       0.335365       0.325465
# 25%         0.433937       0.123091       0.415786       0.424688
# 50%         0.466335       0.145838       0.446424       0.453926
# 75%         0.528795       0.187993       0.515606       0.550457
# max         0.620250       0.552882       0.621255       0.648342
#
#        landmark_13_y  landmark_14_x  ...  cara_prom_z  mano_izquierda_prom_x  \
# count    1279.000000    1279.000000  ...  1279.000000            1279.000000
# mean        0.301197       0.457825  ...    -0.088937               0.483417
# std         0.052822       0.073984  ...     0.223071               0.098114
# min         0.093727       0.342597  ...    -0.636981               0.328891
# 25%         0.259314       0.403120  ...    -0.285063               0.382349
# 50%         0.301147       0.438676  ...    -0.177873               0.478673
# 75%         0.326126       0.520417  ...     0.157974               0.571266
# max         0.411867       0.639208  ...     0.259460               0.702490
#
#        mano_izquierda_prom_y  mano_derecha_prom_x  mano_derecha_prom_y  \
# count            1279.000000          1279.000000          1279.000000
# mean                0.456002             0.460174             0.449996
# std                 0.074954             0.093841             0.074501
# min                -0.096274             0.336345            -0.051874
# 25%                 0.412039             0.373248             0.399531
# 50%                 0.461898             0.458248             0.453085
# 75%                 0.492729             0.561613             0.507860
# max                 0.589525             0.642971             0.581106
#
#        mano_derecha_prom_z  pie_izquierdo_prom_x  pie_izquierdo_prom_z  \
# count          1279.000000           1279.000000           1279.000000
# mean             -0.127564              0.473845              0.141861
# std               0.186599              0.049609              0.102109
# min              -0.685397              0.404562             -0.148754
# 25%              -0.213290              0.417077              0.074340
# 50%              -0.168628              0.455847              0.112993
# 75%               0.071364              0.523465              0.185428
# max               0.398383              0.626911              0.903760
#
#        pie_derecho_prom_x  pie_derecho_prom_z
# count         1279.000000         1279.000000
# mean             0.465749            0.078526
# std              0.045010            0.138733
# min              0.414739           -0.466835
# 25%              0.426408            0.054997
# 50%              0.448175            0.103784
# 75%              0.520932            0.139576
# max              0.660501            0.773345
#
# [8 rows x 32 columns]

# %%
for col in ['landmark_11_z', 'landmark_12_y', 'landmark_12_z',
    'landmark_13_z', 'landmark_14_z', 'landmark_23_z',
    'landmark_24_z', 'cara_prom_y', 'mano_izquierda_prom_z',
    'pie_izquierdo_prom_y', 'pie_derecho_prom_y']:
    df[col] = pd.to_numeric(df[col], errors='coerce')


df['Etiqueta'] = df['Etiqueta'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1279 entries, 0 to 1278
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                1279 non-null   float64
#  1   landmark_10_x          1279 non-null   float64
#  2   landmark_10_y          1279 non-null   float64
#  3   landmark_10_z          1279 non-null   float64
#  4   landmark_11_x          1279 non-null   float64
#  5   landmark_11_y          1279 non-null   float64
#  6   landmark_11_z          1278 non-null   float64
#  7   landmark_12_x          1279 non-null   float64
#  8   landmark_12_y          1278 non-null   float64
#  9   landmark_12_z          1275 non-null   float64
#  10  landmark_13_x          1279 non-null   float64
#  11  landmark_13_y          1279 non-null   float64
#  12  landmark_13_z          1278 non-null   float64
#  13  landmark_14_x          1279 non-null   float64
#  14  landmark_14_y          1279 non-null   float64
#  15  landmark_14_z          1278 non-null   float64
#  16  landmark_23_x          1279 non-null   float64
#  17  landmark_23_y          1279 non-null   float64
#  18  landmark_23_z          1277 non-null   float64
#  19  landmark_24_x          1279 non-null   float64
#  20  landmark_24_y          1279 non-null   float64
#  21  landmark_24_z          1275 non-null   float64
#  22  landmark_25_x          1279 non-null   float64
#  23  landmark_25_y          1279 non-null   float64
#  24  landmark_25_z          1279 non-null   float64
#  25  landmark_26_x          1279 non-null   float64
#  26  landmark_26_y          1279 non-null   float64
#  27  landmark_26_z          1279 non-null   float64
#  28  cara_prom_x            1279 non-null   float64
#  29  cara_prom_y            1277 non-null   float64
#  30  cara_prom_z            1279 non-null   float64
#  31  mano_izquierda_prom_x  1279 non-null   float64
#  32  mano_izquierda_prom_y  1279 non-null   float64
#  33  mano_izquierda_prom_z  1278 non-null   float64
#  34  mano_derecha_prom_x    1279 non-null   float64
#  35  mano_derecha_prom_y    1279 non-null   float64
#  36  mano_derecha_prom_z    1279 non-null   float64
#  37  pie_izquierdo_prom_x   1279 non-null   float64
#  38  pie_izquierdo_prom_y   1255 non-null   float64
#  39  pie_izquierdo_prom_z   1279 non-null   float64
#  40  pie_derecho_prom_x     1279 non-null   float64
#  41  pie_derecho_prom_y     1249 non-null   float64
#  42  pie_derecho_prom_z     1279 non-null   float64
#  43  Etiqueta               1279 non-null   category
# dtypes: category(1), float64(43)
# memory usage: 431.2 KB

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df.describe()
# Out:
#            segundo  landmark_10_x  landmark_10_y  landmark_10_z  \
# count  1279.000000    1279.000000    1279.000000    1279.000000
# mean     22.790438       0.475848       0.075336      -0.082238
# std      12.455513       0.079091       0.056285       0.226325
# min       1.250000       0.330940      -0.187323      -0.613690
# 25%      12.015000       0.427392       0.048981      -0.281034
# 50%      22.790000       0.478018       0.070693      -0.195316
# 75%      33.560000       0.531562       0.104504       0.176308
# max      45.440000       0.628358       0.712694       0.278364
#
#        landmark_11_x  landmark_11_y  landmark_11_z  landmark_12_x  \
# count    1279.000000    1279.000000    1279.000000    1279.000000
# mean        0.475382       0.154698      -0.027752       0.460993
# std         0.076046       0.052296       0.127971       0.072009
# min         0.314174      -0.085738      -0.339542       0.335365
# 25%         0.433937       0.123091      -0.120478       0.415786
# 50%         0.466335       0.145838      -0.026967       0.446424
# 75%         0.528795       0.187993       0.049165       0.515606
# max         0.620250       0.552882       0.331131       0.621255
#
#        landmark_12_y  landmark_12_z  ...  mano_izquierda_prom_z  \
# count    1279.000000    1279.000000  ...            1279.000000
# mean        0.150845      -0.102987  ...              -0.061583
# std         0.046008       0.109598  ...               0.141258
# min        -0.077398      -0.480002  ...              -0.746984
# 25%         0.127638      -0.143050  ...              -0.177516
# 50%         0.144832      -0.100889  ...              -0.029901
# 75%         0.170794      -0.012504  ...               0.025043
# max         0.578790       0.074495  ...               0.390647
#
#        mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# count          1279.000000          1279.000000          1279.000000
# mean              0.460174             0.449996            -0.127564
# std               0.093841             0.074501             0.186599
# min               0.336345            -0.051874            -0.685397
# 25%               0.373248             0.399531            -0.213290
# 50%               0.458248             0.453085            -0.168628
# 75%               0.561613             0.507860             0.071364
# max               0.642971             0.581106             0.398383
#
#        pie_izquierdo_prom_x  pie_izquierdo_prom_y  pie_izquierdo_prom_z  \
# count           1279.000000           1279.000000           1279.000000
# mean               0.473845              0.901715              0.141861
# std                0.049609              0.064540              0.102109
# min                0.404562             -0.196434             -0.148754
# 25%                0.417077              0.894469              0.074340
# 50%                0.455847              0.909469              0.112993
# 75%                0.523465              0.914390              0.185428
# max                0.626911              0.999383              0.903760
#
#        pie_derecho_prom_x  pie_derecho_prom_y  pie_derecho_prom_z
# count         1279.000000         1279.000000         1279.000000
# mean             0.465749            0.912809            0.078526
# std              0.045010            0.063697            0.138733
# min              0.414739           -0.206044           -0.466835
# 25%              0.426408            0.906165            0.054997
# 50%              0.448175            0.913908            0.103784
# 75%              0.520932            0.919804            0.139576
# max              0.660501            0.995374            0.773345
#
# [8 rows x 43 columns]

# %%
df['Etiqueta'].value_counts()
# Out:
# Etiqueta
# inclinado    799
# vertical     480
# Name: count, dtype: int64

# %%
sns.countplot(x='Etiqueta', data=df)
plt.title('Distribución de Etiquetas')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=30, figsize=(10, 8))
plt.show()

# %%
import seaborn as sns

# Calcular correlación entre columnas numéricas
corr = df.select_dtypes(include=['float64', 'int64']).corr()

# Hacer el heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='coolwarm')
plt.title('Mapa de calor de correlaciones')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['landmark_10_x'], df['landmark_10_y'], df['landmark_10_z'], c='blue', s=1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Distribución 3D de landmark_10')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.scatterplot(x='landmark_10_x', y='landmark_10_y', data=df, hue='Etiqueta') # Agrega la columna 'Etiqueta' para el color
plt.title('Gráfico de Dispersión de landmark_10_x vs landmark_10_y')
plt.xlabel('landmark_10_x')
plt.ylabel('landmark_10_y')
plt.show()

# %% [markdown]
# #Datos sentarse

# %%
import pandas as pd

df = pd.read_csv('/content/datosSentarse.csv', delimiter=';')

print(df.head())
# Out:
#    segundo  landmark_10_x        landmark_10_y         landmark_10_z  \
# 0     0.03       0.551442   0.4488238990306854    0.1548767387866974
# 1     0.07       0.518593  0.12187019735574722  -0.14559786021709442
# 2     0.10       0.520899  0.10400626063346863   -0.4073553681373596
# 3     0.13       0.502131  0.08223028481006622   0.11680076271295547
# 4     0.17       0.479251  0.08016263693571091   -0.3915334641933441
#
#    landmark_11_x  landmark_11_y          landmark_11_z  landmark_12_x  \
# 0       0.436936       0.414693    0.20280134677886963       0.622649
# 1       0.398134       0.118534  -0.021578248590230942       0.618078
# 2       0.406712       0.093341   -0.24387483298778534       0.587857
# 3       0.410979       0.051470    0.14080187678337097       0.553293
# 4       0.572276       0.013825   -0.44482675194740295       0.420333
#
#    landmark_12_y         landmark_12_z  ...  mano_derecha_prom_x  \
# 0       0.391021   0.23965895175933838  ...             0.664722
# 1       0.139607   0.02298365719616413  ...             0.673746
# 2       0.101305  -0.20646929740905762  ...             0.671558
# 3       0.045426     0.266024649143219  ...             0.668283
# 4      -0.021577    -0.390133798122406  ...             0.320562
#
#    mano_derecha_prom_y mano_derecha_prom_z  pie_izquierdo_prom_x  \
# 0   0.6423386484384537           -0.371008              0.527354
# 1   0.5523558109998703           -0.109428              0.476405
# 2   0.5158799216151237           -0.205404              0.468161
# 3   0.5030238032341003            0.245388              0.464105
# 4  0.37900909781455994           -0.365803              0.467407
#
#   pie_izquierdo_prom_y pie_izquierdo_prom_z  pie_derecho_prom_x  \
# 0  -0.6726669073104858   0.4982790450255076            0.633576
# 1  -0.8685853083928426   0.3054598867893219            0.579432
# 2  -0.7816593448321024   0.5588438908259074            0.555150
# 3  -0.6219444473584493   0.4759657184282939            0.524525
# 4  -0.5049808124701182   0.8873156507809957            0.468937
#
#     pie_derecho_prom_y   pie_derecho_prom_z  etiqueta
# 0  -0.6935473481814066   0.4580706059932709     depie
# 1  -0.8430390556653341   0.1938297152519226     depie
# 2  -0.8073466618855795   0.4572814106941223     depie
# 3  -0.6547503670056661  0.49018775423367816     depie
# 4  -0.6365304589271545    0.863637367884318     depie
#
# [5 rows x 44 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3741 entries, 0 to 3740
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                3741 non-null   float64
#  1   landmark_10_x          3741 non-null   float64
#  2   landmark_10_y          3741 non-null   object
#  3   landmark_10_z          3741 non-null   object
#  4   landmark_11_x          3741 non-null   float64
#  5   landmark_11_y          3741 non-null   float64
#  6   landmark_11_z          3741 non-null   object
#  7   landmark_12_x          3741 non-null   float64
#  8   landmark_12_y          3741 non-null   float64
#  9   landmark_12_z          3741 non-null   object
#  10  landmark_13_x          3741 non-null   float64
#  11  landmark_13_y          3741 non-null   object
#  12  landmark_13_z          3741 non-null   object
#  13  landmark_14_x          3741 non-null   float64
#  14  landmark_14_y          3741 non-null   object
#  15  landmark_14_z          3741 non-null   object
#  16  landmark_23_x          3741 non-null   float64
#  17  landmark_23_y          3741 non-null   object
#  18  landmark_23_z          3741 non-null   object
#  19  landmark_24_x          3741 non-null   float64
#  20  landmark_24_y          3741 non-null   object
#  21  landmark_24_z          3741 non-null   object
#  22  landmark_25_x          3741 non-null   float64
#  23  landmark_25_y          3741 non-null   object
#  24  landmark_25_z          3741 non-null   object
#  25  landmark_26_x          3741 non-null   float64
#  26  landmark_26_y          3741 non-null   object
#  27  landmark_26_z          3741 non-null   object
#  28  cara_prom_x            3741 non-null   float64
#  29  cara_prom_y            3741 non-null   object
#  30  cara_prom_z            3741 non-null   object
#  31  mano_izquierda_prom_x  3741 non-null   float64
#  32  mano_izquierda_prom_y  3741 non-null   object
#  33  mano_izquierda_prom_z  3741 non-null   object
#  34  mano_derecha_prom_x    3741 non-null   float64
#  35  mano_derecha_prom_y    3741 non-null   object
#  36  mano_derecha_prom_z    3741 non-null   float64
#  37  pie_izquierdo_prom_x   3741 non-null   float64
#  38  pie_izquierdo_prom_y   3741 non-null   object
#  39  pie_izquierdo_prom_z   3741 non-null   object
#  40  pie_derecho_prom_x     3741 non-null   float64
#  41  pie_derecho_prom_y     3741 non-null   object
#  42  pie_derecho_prom_z     3741 non-null   object
#  43  etiqueta               3741 non-null   object
# dtypes: float64(18), object(26)
# memory usage: 1.3+ MB
# None

# %%
for col in ['landmark_10_y', 'landmark_10_z', 'landmark_11_z',
    'landmark_12_z', 'landmark_13_y', 'landmark_13_z',
    'landmark_14_y', 'landmark_14_z', 'landmark_23_y',
    'landmark_23_z', 'landmark_24_y', 'landmark_24_z',
    'landmark_25_y', 'landmark_25_z', 'landmark_26_y',
    'landmark_26_z', 'cara_prom_y', 'cara_prom_z',
    'mano_izquierda_prom_y', 'mano_izquierda_prom_z',
    'mano_derecha_prom_y', 'pie_izquierdo_prom_y',
    'pie_izquierdo_prom_z', 'pie_derecho_prom_y',
    'pie_derecho_prom_z']:
    df[col] = pd.to_numeric(df[col], errors='coerce')


df['Etiqueta'] = df['etiqueta'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3741 entries, 0 to 3740
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                3741 non-null   float64
#  1   landmark_10_x          3741 non-null   float64
#  2   landmark_10_y          3739 non-null   float64
#  3   landmark_10_z          3736 non-null   float64
#  4   landmark_11_x          3741 non-null   float64
#  5   landmark_11_y          3741 non-null   float64
#  6   landmark_11_z          3740 non-null   float64
#  7   landmark_12_x          3741 non-null   float64
#  8   landmark_12_y          3741 non-null   float64
#  9   landmark_12_z          3740 non-null   float64
#  10  landmark_13_x          3741 non-null   float64
#  11  landmark_13_y          3737 non-null   float64
#  12  landmark_13_z          3739 non-null   float64
#  13  landmark_14_x          3741 non-null   float64
#  14  landmark_14_y          3647 non-null   float64
#  15  landmark_14_z          3738 non-null   float64
#  16  landmark_23_x          3741 non-null   float64
#  17  landmark_23_y          3621 non-null   float64
#  18  landmark_23_z          3734 non-null   float64
#  19  landmark_24_x          3741 non-null   float64
#  20  landmark_24_y          3621 non-null   float64
#  21  landmark_24_z          3722 non-null   float64
#  22  landmark_25_x          3741 non-null   float64
#  23  landmark_25_y          3621 non-null   float64
#  24  landmark_25_z          3739 non-null   float64
#  25  landmark_26_x          3741 non-null   float64
#  26  landmark_26_y          3621 non-null   float64
#  27  landmark_26_z          3739 non-null   float64
#  28  cara_prom_x            3741 non-null   float64
#  29  cara_prom_y            3735 non-null   float64
#  30  cara_prom_z            3727 non-null   float64
#  31  mano_izquierda_prom_x  3741 non-null   float64
#  32  mano_izquierda_prom_y  3629 non-null   float64
#  33  mano_izquierda_prom_z  3739 non-null   float64
#  34  mano_derecha_prom_x    3741 non-null   float64
#  35  mano_derecha_prom_y    3619 non-null   float64
#  36  mano_derecha_prom_z    3741 non-null   float64
#  37  pie_izquierdo_prom_x   3741 non-null   float64
#  38  pie_izquierdo_prom_y   2452 non-null   float64
#  39  pie_izquierdo_prom_z   3738 non-null   float64
#  40  pie_derecho_prom_x     3741 non-null   float64
#  41  pie_derecho_prom_y     2273 non-null   float64
#  42  pie_derecho_prom_z     3739 non-null   float64
#  43  etiqueta               3741 non-null   category
#  44  Etiqueta               3741 non-null   category
# dtypes: category(2), float64(43)
# memory usage: 1.2 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3741 entries, 0 to 3740
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                3741 non-null   float64
#  1   landmark_10_x          3741 non-null   float64
#  2   landmark_10_y          3739 non-null   float64
#  3   landmark_10_z          3736 non-null   float64
#  4   landmark_11_x          3741 non-null   float64
#  5   landmark_11_y          3741 non-null   float64
#  6   landmark_11_z          3740 non-null   float64
#  7   landmark_12_x          3741 non-null   float64
#  8   landmark_12_y          3741 non-null   float64
#  9   landmark_12_z          3740 non-null   float64
#  10  landmark_13_x          3741 non-null   float64
#  11  landmark_13_y          3737 non-null   float64
#  12  landmark_13_z          3739 non-null   float64
#  13  landmark_14_x          3741 non-null   float64
#  14  landmark_14_y          3647 non-null   float64
#  15  landmark_14_z          3738 non-null   float64
#  16  landmark_23_x          3741 non-null   float64
#  17  landmark_23_y          3621 non-null   float64
#  18  landmark_23_z          3734 non-null   float64
#  19  landmark_24_x          3741 non-null   float64
#  20  landmark_24_y          3621 non-null   float64
#  21  landmark_24_z          3722 non-null   float64
#  22  landmark_25_x          3741 non-null   float64
#  23  landmark_25_y          3621 non-null   float64
#  24  landmark_25_z          3739 non-null   float64
#  25  landmark_26_x          3741 non-null   float64
#  26  landmark_26_y          3621 non-null   float64
#  27  landmark_26_z          3739 non-null   float64
#  28  cara_prom_x            3741 non-null   float64
#  29  cara_prom_y            3735 non-null   float64
#  30  cara_prom_z            3727 non-null   float64
#  31  mano_izquierda_prom_x  3741 non-null   float64
#  32  mano_izquierda_prom_y  3629 non-null   float64
#  33  mano_izquierda_prom_z  3739 non-null   float64
#  34  mano_derecha_prom_x    3741 non-null   float64
#  35  mano_derecha_prom_y    3619 non-null   float64
#  36  mano_derecha_prom_z    3741 non-null   float64
#  37  pie_izquierdo_prom_x   3741 non-null   float64
#  38  pie_izquierdo_prom_y   2452 non-null   float64
#  39  pie_izquierdo_prom_z   3738 non-null   float64
#  40  pie_derecho_prom_x     3741 non-null   float64
#  41  pie_derecho_prom_y     2273 non-null   float64
#  42  pie_derecho_prom_z     3739 non-null   float64
#  43  etiqueta               3741 non-null   category
#  44  Etiqueta               3741 non-null   category
# dtypes: category(2), float64(43)
# memory usage: 1.2 MB

# %%
df['Etiqueta'].value_counts()
# Out:
# Etiqueta
# depie      2073
# sentado    1668
# Name: count, dtype: int64

# %%
sns.countplot(x='Etiqueta', data=df)
plt.title('Distribución de Etiquetas')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=30, figsize=(10, 8))
plt.show()

# %%
import seaborn as sns

# Calcular correlación entre columnas numéricas
corr = df.select_dtypes(include=['float64', 'int64']).corr()

# Hacer el heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='coolwarm')
plt.title('Mapa de calor de correlaciones')
plt.show()
