# %%
import pandas as pd

# %%
df_agacharseD1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseD1.csv',delimiter=';')
df_agacharseD1 = df_agacharseD1 = df_agacharseD1.drop('Unnamed: 43', axis=1)
df_agacharseD1.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.519331       0.357692      -0.156593       0.557772
# 1     0.07       0.519291       0.358392      -0.179541       0.557721
# 2     0.10       0.519278       0.358941      -0.175015       0.557587
# 3     0.13       0.519231       0.359378      -0.172069       0.557482
# 4     0.17       0.519205       0.359543      -0.170336       0.557410
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.427935      -0.043421       0.484074       0.418862      -0.053209
# 1       0.427952      -0.060467       0.484069       0.419904      -0.067065
# 2       0.427935      -0.057566       0.484068       0.420497      -0.065557
# 3       0.427900      -0.055857       0.484062       0.420832      -0.063677
# 4       0.427830      -0.054852       0.484062       0.421015      -0.062663
#
#    ...  mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# ...

# %%
df_agacharseD1['landmark_23_z']
# Out:
# 0      0.0024031265638768673
# 1      0.0018029457423835993
# 2      0.0016051271231845021
# 3      0.0010440533515065908
# 4      0.0005256484146229923
#                ...
# 211     0.002262550638988614
# 212     0.002253412501886487
# 213      0.00236369832418859
# 214     0.002811288693919778
# 215    0.0027984892949461937
# Name: landmark_23_z, Length: 216, dtype: object

# %%
df_agacharseI1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseI1.csv',delimiter=';')
df_agacharseI1['Vista'] = 'frontal'
df_agacharseI1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                112 non-null    float64
#  1   landmark_10_x          112 non-null    float64
#  2   landmark_10_y          112 non-null    float64
#  3   landmark_10_z          112 non-null    float64
#  4   landmark_11_x          112 non-null    float64
#  5   landmark_11_y          112 non-null    float64
#  6   landmark_11_z          112 non-null    float64
#  7   landmark_12_x          112 non-null    float64
#  8   landmark_12_y          112 non-null    float64
#  9   landmark_12_z          112 non-null    float64
#  10  landmark_13_x          112 non-null    float64
#  11  landmark_13_y          112 non-null    float64
#  12  landmark_13_z          112 non-null    float64
#  13  landmark_14_x          112 non-null    float64
# ...

# %%
df_agacharseI1
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.480289       0.307860      -0.203973       0.518457
# 1       0.07       0.480486       0.307829      -0.186392       0.518446
# 2       0.10       0.480670       0.307840      -0.182568       0.518429
# 3       0.13       0.480821       0.307924      -0.183372       0.518424
# 4       0.17       0.481020       0.308277      -0.191914       0.518423
# ..       ...            ...            ...            ...            ...
# 107     3.60       0.483214       0.312629      -0.194257       0.519039
# 108     3.63       0.483051       0.312723      -0.188025       0.518990
# 109     3.67       0.482923       0.312644      -0.195543       0.518873
# 110     3.70       0.482815       0.312563      -0.199383       0.518789
# 111     3.73       0.482615       0.312690      -0.201597       0.518769
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_agacharseI2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseI2.csv',delimiter=';')
df_agacharseI2['Vista'] = 'frontal'
df_agacharseI2 = df_agacharseI2.drop('Unnamed: 43', axis=1)
df_agacharseI2 = df_agacharseI2.drop('Vertical', axis=1)
df_agacharseI2
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.484084       0.315976      -0.222748       0.520377
# 1       0.07       0.484036       0.315821      -0.226796       0.520354
# 2       0.10       0.483988       0.315727      -0.227227       0.520338
# 3       0.13       0.483984       0.315679      -0.222871       0.520335
# 4       0.17       0.483986       0.315673      -0.222640       0.520342
# ..       ...            ...            ...            ...            ...
# 107     3.60       0.481148       0.304148      -0.159528       0.517467
# 108     3.63       0.481048       0.304222      -0.161026       0.517489
# 109     3.67       0.480923       0.304283      -0.159547       0.517527
# 110     3.70       0.480858       0.304324      -0.161537       0.517558
# 111     3.73       0.480834       0.304360      -0.167818       0.517568
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_agacharseK1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseK1.csv',delimiter=';')
df_agacharseK1 = df_agacharseK1.drop('Unnamed: 43', axis=1)
df_agacharseK1 = df_agacharseK1.drop('Vertical', axis=1)
df_agacharseK1['Vista'] = 'frontal'
df_agacharseK1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                220 non-null    float64
#  1   landmark_10_x          220 non-null    float64
#  2   landmark_10_y          220 non-null    float64
#  3   landmark_10_z          220 non-null    float64
#  4   landmark_11_x          220 non-null    float64
#  5   landmark_11_y          220 non-null    float64
#  6   landmark_11_z          220 non-null    float64
#  7   landmark_12_x          220 non-null    float64
#  8   landmark_12_y          220 non-null    float64
#  9   landmark_12_z          220 non-null    float64
#  10  landmark_13_x          220 non-null    float64
#  11  landmark_13_y          220 non-null    float64
#  12  landmark_13_z          220 non-null    float64
#  13  landmark_14_x          220 non-null    float64
# ...

# %%
df_agacharseK2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseK2.csv',delimiter=';')
df_agacharseK2 = df_agacharseK2.drop('Unnamed: 43', axis=1)
df_agacharseK2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                162 non-null    float64
#  1   landmark_10_x          162 non-null    float64
#  2   landmark_10_y          162 non-null    float64
#  3   landmark_10_z          162 non-null    float64
#  4   landmark_11_x          162 non-null    float64
#  5   landmark_11_y          162 non-null    float64
#  6   landmark_11_z          162 non-null    float64
#  7   landmark_12_x          162 non-null    float64
#  8   landmark_12_y          162 non-null    float64
#  9   landmark_12_z          162 non-null    float64
#  10  landmark_13_x          162 non-null    float64
#  11  landmark_13_y          162 non-null    float64
#  12  landmark_13_z          162 non-null    float64
#  13  landmark_14_x          162 non-null    float64
# ...

# %%
df_agacharseD1_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseLadoD1.csv',delimiter=';')
df_agacharseD1_lateral = df_agacharseD1_lateral.drop('Unnamed: 43', axis=1)
df_agacharseD1_lateral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                210 non-null    float64
#  1   landmark_10_x          210 non-null    float64
#  2   landmark_10_y          210 non-null    float64
#  3   landmark_10_z          210 non-null    float64
#  4   landmark_11_x          210 non-null    float64
#  5   landmark_11_y          210 non-null    float64
#  6   landmark_11_z          210 non-null    float64
#  7   landmark_12_x          210 non-null    float64
#  8   landmark_12_y          210 non-null    float64
#  9   landmark_12_z          210 non-null    float64
#  10  landmark_13_x          210 non-null    float64
#  11  landmark_13_y          210 non-null    float64
#  12  landmark_13_z          210 non-null    float64
#  13  landmark_14_x          210 non-null    float64
# ...

# %%
df_agacharseI2_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/agacharseLadoI2Etq.csv')
df_agacharseI2_lateral['Vista'] = 'lateral'
df_agacharseI2_lateral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                188 non-null    float64
#  1   landmark_10_x          188 non-null    float64
#  2   landmark_10_y          188 non-null    float64
#  3   landmark_10_z          188 non-null    float64
#  4   landmark_11_x          188 non-null    float64
#  5   landmark_11_y          188 non-null    float64
#  6   landmark_11_z          188 non-null    float64
#  7   landmark_12_x          188 non-null    float64
#  8   landmark_12_y          188 non-null    float64
#  9   landmark_12_z          188 non-null    float64
#  10  landmark_13_x          188 non-null    float64
#  11  landmark_13_y          188 non-null    float64
#  12  landmark_13_z          188 non-null    float64
#  13  landmark_14_x          188 non-null    float64
# ...

# %%
df_agacharseK2_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/agacharseLadoK2Etq.csv')
df_agacharseK2_lateral['Vista'] = 'lateral'
df_agacharseK2_lateral
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.490981       0.325046      -0.162749       0.477764
# 1       0.07       0.492023       0.325555      -0.158449       0.478156
# 2       0.10       0.494458       0.326422      -0.158734       0.478529
# 3       0.13       0.497402       0.328637      -0.143898       0.478480
# 4       0.17       0.500092       0.331497      -0.144727       0.479564
# ..       ...            ...            ...            ...            ...
# 176     5.90       0.469859       0.325416      -0.217752       0.470072
# 177     5.93       0.469716       0.325513      -0.215766       0.469388
# 178     5.97       0.469290       0.325599      -0.210888       0.469344
# 179     6.00       0.469164       0.325665      -0.206123       0.469150
# 180     6.03       0.469204       0.325797      -0.203591       0.469314
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_agacharseS1_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/agacharseLadoS1Etq.csv')
df_agacharseS1_lateral['Vista'] = 'lateral'
df_agacharseS1_lateral
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.548727       0.339102      -0.121978       0.520344
# 1       0.07       0.548613       0.340043      -0.119984       0.520314
# 2       0.10       0.548614       0.340236      -0.119809       0.520304
# 3       0.13       0.548775       0.340260      -0.119625       0.520303
# 4       0.17       0.548967       0.340384      -0.120983       0.520418
# ..       ...            ...            ...            ...            ...
# 213     7.13       0.548796       0.364165      -0.107219       0.522336
# 214     7.17       0.548880       0.363909      -0.108589       0.522182
# 215     7.20       0.548912       0.363770      -0.108489       0.522012
# 216     7.23       0.548922       0.363614      -0.108349       0.521826
# 217     7.27       0.548959       0.363600      -0.106637       0.521613
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_caminandoD1= pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoD1.csv',delimiter=';')
df_caminandoD1 = df_caminandoD1.drop('Unnamed: 43', axis=1)
df_caminandoD1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                149 non-null    float64
#  1   landmark_10_x          149 non-null    float64
#  2   landmark_10_y          149 non-null    float64
#  3   landmark_10_z          149 non-null    float64
#  4   landmark_11_x          149 non-null    float64
#  5   landmark_11_y          149 non-null    float64
#  6   landmark_11_z          149 non-null    float64
#  7   landmark_12_x          149 non-null    float64
#  8   landmark_12_y          149 non-null    float64
#  9   landmark_12_z          149 non-null    float64
#  10  landmark_13_x          149 non-null    float64
#  11  landmark_13_y          149 non-null    float64
#  12  landmark_13_z          149 non-null    float64
#  13  landmark_14_x          149 non-null    float64
# ...

# %%
df_caminandoD2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoD2.csv',delimiter=';')
df_caminandoD2 = df_caminandoD2.drop('Unnamed: 43', axis=1)
df_caminandoD2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                135 non-null    float64
#  1   landmark_10_x          135 non-null    float64
#  2   landmark_10_y          135 non-null    float64
#  3   landmark_10_z          135 non-null    float64
#  4   landmark_11_x          135 non-null    float64
#  5   landmark_11_y          135 non-null    float64
#  6   landmark_11_z          135 non-null    float64
#  7   landmark_12_x          135 non-null    float64
#  8   landmark_12_y          135 non-null    float64
#  9   landmark_12_z          135 non-null    float64
#  10  landmark_13_x          135 non-null    float64
#  11  landmark_13_y          135 non-null    float64
#  12  landmark_13_z          135 non-null    object
#  13  landmark_14_x          135 non-null    float64
# ...

# %%
df_caminandoI1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoI1.csv',delimiter=';')
df_caminandoI1 = df_caminandoI1.drop('Unnamed: 43', axis=1)
df_caminandoI1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   segundo                136 non-null    float64
#  1   landmark_10_x          136 non-null    float64
#  2   landmark_10_y          136 non-null    float64
#  3   landmark_10_z          136 non-null    float64
#  4   landmark_11_x          136 non-null    float64
#  5   landmark_11_y          136 non-null    float64
#  6   landmark_11_z          136 non-null    float64
#  7   landmark_12_x          136 non-null    float64
#  8   landmark_12_y          136 non-null    float64
#  9   landmark_12_z          136 non-null    float64
#  10  landmark_13_x          136 non-null    float64
#  11  landmark_13_y          136 non-null    float64
#  12  landmark_13_z          136 non-null    float64
#  13  landmark_14_x          136 non-null    float64
# ...

# %%
df_caminandoI2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoI2.csv',delimiter=';')
df_caminandoI2 = df_caminandoI2.drop('Unnamed: 43', axis=1)
df_caminandoI2.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.485911       0.218679      -0.144500       0.516753
# 1     0.07       0.485934       0.218178      -0.122676       0.516684
# 2     0.10       0.485952       0.218056      -0.127546       0.516695
# 3     0.13       0.485942       0.218033      -0.130672       0.516698
# 4     0.17       0.485908       0.217985      -0.132386       0.516699
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.265264      -0.051137       0.466833       0.267586      -0.050962
# 1       0.265107      -0.024782       0.466854       0.267489      -0.034748
# 2       0.265151      -0.027968       0.466855       0.267526      -0.038549
# 3       0.265500      -0.032399       0.466867       0.267716      -0.039937
# 4       0.266021      -0.033115       0.466865       0.268059      -0.041134
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y mano_derecha_prom_z  \
# ...

# %%
df_caminandoK1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoK1.csv',delimiter=';')
df_caminandoK1 = df_caminandoK1.drop('Unnamed: 43', axis=1)
df_caminandoK1.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.505180       0.236839      -0.140644       0.532224
# 1     0.07       0.505179       0.236725      -0.143319       0.532314
# 2     0.10       0.505189       0.236630      -0.147018       0.532461
# 3     0.13       0.505169       0.236558      -0.149098       0.532617
# 4     0.17       0.505159       0.236523      -0.149773       0.532663
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.275105      -0.048575       0.484757       0.281313      -0.048855
# 1       0.275345      -0.049048       0.484786       0.281524      -0.055588
# 2       0.275582      -0.050097       0.484805       0.281547      -0.061407
# 3       0.275803      -0.054587       0.484873       0.281538      -0.061804
# 4       0.275870      -0.055891       0.484984       0.281471      -0.062268
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_caminandoK2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoK2.csv',delimiter=';')
df_caminandoK2 = df_caminandoK2.drop('Unnamed: 43', axis=1)
df_caminandoK2.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.17       0.451051       0.423070       0.157561       0.443219
# 1     0.20       0.453775       0.401944       0.133069       0.437227
# 2     0.23       0.454062       0.399411       0.106643       0.436855
# 3     0.27       0.455402       0.397475       0.126674       0.435407
# 4     0.43       0.454798       0.408250       0.220413       0.433850
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.423790       0.098730       0.467234       0.421387       0.135156
# 1       0.401059       0.107589       0.471835       0.410836       0.148392
# 2       0.399890       0.093147       0.473091       0.408603       0.127130
# 3       0.404036       0.093251       0.475011       0.397641       0.150508
# 4       0.406387       0.112067       0.476132       0.397100       0.176291
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y mano_derecha_prom_z  \
# ...

# %%
df_caminandoS1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS1.csv',delimiter=';')
df_caminandoS1 = df_caminandoS1.drop('Unnamed: 43', axis=1)
df_caminandoS1.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.535932       0.182026      -0.199147       0.572615
# 1     0.07       0.536286       0.182021      -0.190995       0.572557
# 2     0.10       0.536409       0.182008      -0.185068       0.572413
# 3     0.13       0.536448       0.181996      -0.184508       0.572381
# 4     0.17       0.536587       0.182001      -0.186885       0.572314
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.228659      -0.092679       0.514490       0.228010      -0.094318
# 1       0.229005      -0.086735       0.514308       0.227451      -0.089996
# 2       0.229182      -0.081452       0.514190       0.227078      -0.086089
# 3       0.229246      -0.080371       0.514114       0.226639      -0.085103
# 4       0.229244      -0.082078       0.513974       0.226399      -0.085332
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_caminandoS2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS2.csv',delimiter=';')
df_caminandoS2 = df_caminandoS2.drop('Unnamed: 43', axis=1)
df_caminandoS2 = df_caminandoS2.drop('Vista', axis=1)
df_caminandoS2.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.572155       0.293388      -0.196815       0.607396
# 1     0.07       0.572540       0.291932      -0.184707       0.607223
# 2     0.10       0.572872       0.291382      -0.183163       0.607185
# 3     0.13       0.573183       0.290920      -0.178856       0.607200
# 4     0.17       0.573286       0.290875      -0.182488       0.607214
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.338900      -0.082125       0.549111       0.340296      -0.088017
# 1       0.338831      -0.070735       0.549103       0.340317      -0.081993
# 2       0.338835      -0.067778       0.549077       0.340382      -0.079922
# 3       0.338795      -0.064570       0.549103       0.340382      -0.076426
# 4       0.338785      -0.067718       0.549133       0.340341      -0.078263
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_girandoD1_BA = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosAbiertosD1.csv',delimiter=';')
df_girandoD1_BA
df_girandoD1_BA = df_girandoD1_BA.drop('Unnamed: 43', axis=1)
df_girandoD1_BA = df_girandoD1_BA.drop('Vista', axis=1)
df_girandoD1_BA.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.478885       0.237691      -0.191908       0.522262
# 1     0.07       0.478901       0.237697      -0.211287       0.522310
# 2     0.10       0.478876       0.237662      -0.220401       0.522343
# 3     0.13       0.478848       0.237638      -0.221902       0.522344
# 4     0.17       0.478811       0.237557      -0.217486       0.522343
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.323269      -0.056036       0.438658       0.313198      -0.069032
# 1       0.323484      -0.076090       0.438663       0.314327      -0.077049
# 2       0.323615      -0.084306       0.438668       0.314916      -0.083667
# 3       0.323606      -0.083459       0.438668       0.315076      -0.086449
# 4       0.323576      -0.078162       0.438666       0.315093      -0.086240
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_girandoD2_BA = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosAbiertosD2.csv',delimiter=';')
df_girandoD2_BA = df_girandoD2_BA.drop('Unnamed: 43', axis=1)
df_girandoD2_BA = df_girandoD2_BA.drop('Vista', axis=1)
df_girandoD2_BA.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.474384       0.271855      -0.243479       0.514523
# 1     0.07       0.474416       0.273595      -0.265922       0.514520
# 2     0.10       0.474418       0.274796      -0.271162       0.514520
# 3     0.13       0.474403       0.275721      -0.274706       0.514479
# 4     0.17       0.474380       0.276327      -0.278893       0.514429
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.343540      -0.124375       0.428647       0.337364      -0.095709
# 1       0.344885      -0.134734       0.428637       0.337154      -0.124970
# 2       0.345405      -0.139945       0.428632       0.336937      -0.129224
# 3       0.345521      -0.142938       0.428612       0.336810      -0.131029
# 4       0.345596      -0.145084       0.428558       0.336665      -0.134612
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_girandoI2_BA = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosAbiertosI2.csv',delimiter=';')
df_girandoI2_BA = df_girandoI2_BA.drop('Unnamed: 43', axis=1)
df_girandoI2_BA.head()
#
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.463271       0.218365      -0.237641       0.501765
# 1     0.07       0.463423       0.217461      -0.191398       0.501330
# 2     0.10       0.463539       0.216928      -0.196460       0.501047
# 3     0.13       0.463672       0.216801      -0.193801       0.500976
# 4     0.17       0.463906       0.216805      -0.187991       0.500926
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0
# 4       0.17       0.564065       0.299458  -0.32793575525283813
# ..       ...            ...            ...                   ...
# 142     4.77       0.535490       0.271419   -0.2765868306159973
# 143     4.80       0.535450       0.271190   -0.2855631411075592
# 144     4.83       0.535371       0.271206   -0.2841123938560486
# 145     4.87       0.535164       0.271009   -0.2837978005409241
# 146     4.90       0.535068       0.270460   -0.2757211923599243
#
#      landmark_11_x  landmark_11_y  landmark_11_z  landmark_12_x  \
# 0         0.620019       0.359988      -0.162148       0.529769
# ...

# %%
df_girandoD1_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosD1.csv',delimiter=';')
df_girandoD1_BC = df_girandoD1_BC.drop('Unnamed: 43', axis=1)
df_girandoD1_BC = df_girandoD1_BC.drop('Vista', axis=1)
df_girandoD1_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.484630       0.293702      -0.188869       0.525813
# 1     0.07       0.484573       0.293588      -0.191216       0.525719
# 2     0.10       0.484514       0.293415      -0.191132       0.525496
# 3     0.13       0.484296       0.292718      -0.191070       0.525068
# 4     0.17       0.484068       0.292631      -0.192221       0.524393
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# 0       0.368042      -0.074683       0.449568       0.366447
# 1       0.368022      -0.076959       0.449554       0.366435
# 2       0.368021      -0.076852       0.449326       0.366456
# 3       0.368021      -0.075926       0.448681       0.366584
# 4       0.368069      -0.075892       0.447974       0.366691
#
#           landmark_12_z  ...  mano_derecha_prom_x  mano_derecha_prom_y  \
# 0  -0.06477855890989304  ...             0.440878             0.594932
# ...

# %%
df_girandoD2_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosD2.csv',delimiter=';')
df_girandoD2_BC = df_girandoD2_BC.drop('Unnamed: 43', axis=1)
df_girandoD2_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.377502       0.208938      -0.223858       0.432252
# 1     0.07       0.377928       0.211064      -0.254352       0.432262
# 2     0.10       0.378386       0.212613      -0.258089       0.432256
# 3     0.13       0.378526       0.213889      -0.266411       0.432204
# 4     0.17       0.378622       0.214878      -0.267183       0.432001
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.297094      -0.115829       0.340728       0.291236      -0.090850
# 1       0.299193      -0.130573       0.340338       0.292564      -0.111855
# 2       0.301054      -0.133413       0.340103       0.293437      -0.117550
# 3       0.302771      -0.138906       0.339733       0.294175      -0.125343
# 4       0.303274      -0.139104       0.339132       0.294532      -0.125157
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_girandoD3_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosD3.csv',delimiter=';')
df_girandoD3_BC = df_girandoD3_BC.drop('Unnamed: 43', axis=1)
df_girandoD3_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.415226       0.291730      -0.161502       0.453978
# 1     0.07       0.415281       0.291475      -0.138985       0.454031
# 2     0.10       0.415518       0.291472      -0.136913       0.454057
# 3     0.13       0.415596       0.290993      -0.143349       0.454168
# 4     0.17       0.415741       0.290748      -0.145938       0.454304
#
#    landmark_11_y          landmark_11_z  landmark_12_x  landmark_12_y  \
# 0       0.353615   -0.06149625405669212       0.388637       0.345760
# 1       0.354239   -0.04684877395629883       0.388638       0.346672
# 2       0.354942   -0.04375249147415161       0.388673       0.347182
# 3       0.355545   -0.04748181253671646       0.388769       0.347471
# 4       0.355846  -0.048821642994880676       0.388937       0.347744
#
#    landmark_12_z  ...  mano_derecha_prom_x  mano_derecha_prom_y  \
# ...

# %%
df_girandoD4_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosD4.csv',delimiter=';')
df_girandoD4_BC = df_girandoD4_BC.drop('Unnamed: 43', axis=1)
df_girandoD4_BC = df_girandoD4_BC.drop('Vista', axis=1)
df_girandoD4_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.586538       0.336129      -0.175561       0.617408
# 1     0.07       0.586603       0.335941      -0.170985       0.617195
# 2     0.10       0.586541       0.335900      -0.171116       0.616947
# 3     0.13       0.585295       0.335866      -0.177751       0.616778
# 4     0.17       0.584165       0.335882      -0.191821       0.616685
#
#    landmark_11_y          landmark_11_z  landmark_12_x  landmark_12_y  \
# 0       0.402793   -0.06624728441238403       0.547774       0.399764
# 1       0.403111  -0.042237281799316406       0.548316       0.399495
# 2       0.403537    -0.0422712080180645       0.548460       0.399477
# 3       0.403739  -0.047380439937114716       0.548591       0.399322
# 4       0.404054  -0.052807439118623734       0.548571       0.399327
#
#    landmark_12_z  ...  mano_derecha_prom_x  mano_derecha_prom_y  \
# ...

# %%
df_girandoI1_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosI1.csv',delimiter=';')
df_girandoI1_BC = df_girandoI1_BC.drop('Unnamed: 43', axis=1)
df_girandoI1_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.498741       0.289228      -0.201641       0.537859
# 1     0.07       0.498990       0.289151      -0.199543       0.537845
# 2     0.10       0.499159       0.289115      -0.199326       0.537836
# 3     0.13       0.499250       0.289036      -0.199106       0.537685
# 4     0.17       0.499291       0.289026      -0.201013       0.537570
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.352892      -0.069148       0.471779       0.347324      -0.068378
# 1       0.352907      -0.059512       0.471838       0.347230      -0.068404
# 2       0.352916      -0.057035       0.471869       0.347165      -0.068485
# 3       0.352913      -0.053552       0.471870       0.347059      -0.068269
# 4       0.352893      -0.055641       0.471865       0.346933      -0.069554
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y mano_derecha_prom_z  \
# ...

# %%
df_girandoI2_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosI2.csv',delimiter=';')
df_girandoI2_BC = df_girandoI2_BC.drop('Unnamed: 43', axis=1)
df_girandoI2_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.483305       0.313318      -0.185298       0.521367
# 1     0.07       0.483647       0.313310      -0.182657       0.521228
# 2     0.10       0.483992       0.313319      -0.182736       0.521200
# 3     0.13       0.484263       0.313324      -0.182773       0.521200
# 4     0.17       0.484459       0.313338      -0.182553       0.521239
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.373145      -0.054783       0.459512       0.369271      -0.060246
# 1       0.373122      -0.048830       0.459273       0.369596      -0.059969
# 2       0.373068      -0.048514       0.459181       0.369736      -0.061417
# 3       0.373058      -0.047958       0.459171       0.369856      -0.061786
# 4       0.372993      -0.047627       0.459173       0.369955      -0.062044
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y mano_derecha_prom_z  \
# ...

# %%
df_girandoK1_BC = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosCerradosK1.csv',delimiter=';')
df_girandoK1_BC = df_girandoK1_BC.drop('Unnamed: 43', axis=1)
df_girandoK1_BC.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.493211       0.342252      -0.221217       0.528578
# 1     0.07       0.493362       0.341644      -0.206301       0.528416
# 2     0.10       0.493474       0.341298      -0.203954       0.528538
# 3     0.13       0.493717       0.341182      -0.205079       0.528814
# 4     0.17       0.494007       0.340864      -0.203928       0.529076
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.396005      -0.075304       0.464029       0.402828      -0.097111
# 1       0.394483      -0.063080       0.464017       0.402893      -0.088154
# 2       0.394099      -0.064540       0.464059       0.402892      -0.085166
# 3       0.394052      -0.066200       0.464225       0.402903      -0.084905
# 4       0.394068      -0.067100       0.464553       0.402941      -0.084500
#
#    ...  mano_derecha_prom_x  mano_derecha_prom_y  mano_derecha_prom_z  \
# ...

# %%
df_reversaD1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de reversaD1.csv',delimiter=';')
df_reversaD1['Etiqueta'] = 'alejandose'
df_reversaD1.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.354138      -0.225754       0.479366       0.362947       0.027892
# 1       0.354409      -0.212448       0.480510       0.363115       0.036369
# 2       0.355405      -0.207396       0.480899       0.364116       0.042623
# 3       0.356017      -0.207006       0.481599       0.364303       0.042705
# 4       0.356353      -0.210393       0.482223       0.364359       0.040520
#
#    ...  mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# ...

# %%
df_sentadoK4_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/sentandoseLadoK4.csv',delimiter=';')
df_sentadoK4_lateral['Vista'] = 'lateral'
df_sentadoK4_lateral.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.47       0.484828       0.526801      -0.258924       0.464702
# 1     0.50       0.485156       0.551160      -0.178625       0.488519
# 2     0.53       0.492803       0.591432       0.091406       0.484328
# 3     0.57       0.494270       0.577132      -0.026873       0.481276
# 4     0.60       0.495530       0.603117      -0.033068       0.477752
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.549889      -0.276305       0.492516       0.547013      -0.165053
# 1       0.576989      -0.227059       0.479697       0.561626      -0.092092
# 2       0.605000       0.040849       0.492861       0.573647       0.198080
# 3       0.598577      -0.059252       0.494637       0.576821       0.096694
# 4       0.608215      -0.094225       0.494450       0.593024       0.086422
#
#    ...  mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# ...

# %%
df_agacharse = pd.concat([df_agacharseD1, df_agacharseI1, df_agacharseI2, df_agacharseK1, df_agacharseK2,df_agacharseD1_lateral,df_agacharseI2_lateral,df_agacharseK2_lateral], ignore_index=True)

# %%
df_caminando = pd.concat([df_caminandoD1, df_caminandoD2,df_caminandoI1,df_caminandoI2,df_caminandoK1,df_caminandoK2])

# %%
df_girar = pd.concat([df_girandoD1_BA,df_girandoD2_BA,df_girandoI2_BA,df_girandoK1_BA,df_girandoK2_BA, df_girandoD1_BC,df_girandoD2_BC,df_girandoD3_BC,df_girandoD4_BC,df_girandoI1_BC,df_girandoI2_BC,df_girandoK1_BC])

# %%
df_reversa = pd.concat([df_reversaD1,df_reversaD2,df_reversaI1,df_reversaI2,df_reversaK1])

# %%
df_sentarse = pd.concat([df_sentadoD1,df_sentadoD2,df_sentadoI1,df_sentadoI2,df_sentadoK1,df_sentadoK2,df_sentadoD1_lateral,df_sentadoD2_lateral,df_sentadoI1_lateral,df_sentadoI2_lateral,df_sentadoI3_lateral,df_sentadoK1_lateral,df_sentado_K3_lateral,df_sentadoK4_lateral])

# %%
df_agacharse = df_agacharse.drop('Unnamed: 43', axis=1)
df_agacharse.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.519331       0.357692      -0.156593       0.557772
# 1     0.07       0.519291       0.358392      -0.179541       0.557721
# 2     0.10       0.519278       0.358941      -0.175015       0.557587
# 3     0.13       0.519231       0.359378      -0.172069       0.557482
# 4     0.17       0.519205       0.359543      -0.170336       0.557410
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.427935      -0.043421       0.484074       0.418862      -0.053209
# 1       0.427952      -0.060467       0.484069       0.419904      -0.067065
# 2       0.427935      -0.057566       0.484068       0.420497      -0.065557
# 3       0.427900      -0.055857       0.484062       0.420832      -0.063677
# 4       0.427830      -0.054852       0.484062       0.421015      -0.062663
#
#    ...  mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# ...

# %%
df_sentadoI2_lateral.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.471354       0.296112      -0.107085       0.451013
# 1     0.07       0.471278       0.295286      -0.108427       0.450807
# 2     0.10       0.471228       0.294869      -0.108422       0.450566
# 3     0.13       0.471250       0.294769      -0.109677       0.450259
# 4     0.17       0.471449       0.294725      -0.109379       0.449839
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.346298       0.067771       0.445226       0.338360      -0.216348
# 1       0.345712       0.065746       0.444542       0.338643      -0.216334
# 2       0.345692       0.065828       0.443951       0.338978      -0.215645
# 3       0.345659       0.064411       0.443736       0.339100      -0.215642
# 4       0.345601       0.064497       0.443712       0.339174      -0.213991
#
#    ...  mano_derecha_prom_y  mano_derecha_prom_z  pie_izquierdo_prom_x  \
# ...

# %%
df_caminando.isnull().sum()
# Out:
# segundo                  0
# landmark_10_x            0
# landmark_10_y            0
# landmark_10_z            0
# landmark_11_x            0
# landmark_11_y            0
# landmark_11_z            0
# landmark_12_x            0
# landmark_12_y            0
# landmark_12_z            0
# landmark_13_x            0
# landmark_13_y            0
# landmark_13_z            0
# landmark_14_x            0
# landmark_14_y            0
# landmark_14_z            0
# landmark_23_x            0
# landmark_23_y            0
# landmark_23_z            0
# landmark_24_x            0
# landmark_24_y            0
# landmark_24_z            0
# landmark_25_x            0
# landmark_25_y            0
# landmark_25_z            0
# landmark_26_x            0
# landmark_26_y            0
# landmark_26_z            0
# cara_prom_x              0
# cara_prom_y              0
# cara_prom_z              0
# mano_izquierda_prom_x    0
# mano_izquierda_prom_y    0
# mano_izquierda_prom_z    0
# ...

# %%
df_reversa.isnull().sum()
# Out:
# segundo                  0
# landmark_10_x            0
# landmark_10_y            0
# landmark_10_z            0
# landmark_11_x            0
# landmark_11_y            0
# landmark_11_z            0
# landmark_12_x            0
# landmark_12_y            0
# landmark_12_z            0
# landmark_13_x            0
# landmark_13_y            0
# landmark_13_z            0
# landmark_14_x            0
# landmark_14_y            0
# landmark_14_z            0
# landmark_23_x            0
# landmark_23_y            0
# landmark_23_z            0
# landmark_24_x            0
# landmark_24_y            0
# landmark_24_z            0
# landmark_25_x            0
# landmark_25_y            0
# landmark_25_z            0
# landmark_26_x            0
# landmark_26_y            0
# landmark_26_z            0
# cara_prom_x              0
# cara_prom_y              0
# cara_prom_z              0
# mano_izquierda_prom_x    0
# mano_izquierda_prom_y    0
# mano_izquierda_prom_z    0
# ...

# %%
df_girar.isnull().sum()
# Out:
# segundo                  0
# landmark_10_x            0
# landmark_10_y            0
# landmark_10_z            0
# landmark_11_x            0
# landmark_11_y            0
# landmark_11_z            0
# landmark_12_x            0
# landmark_12_y            0
# landmark_12_z            0
# landmark_13_x            0
# landmark_13_y            0
# landmark_13_z            0
# landmark_14_x            0
# landmark_14_y            0
# landmark_14_z            0
# landmark_23_x            0
# landmark_23_y            0
# landmark_23_z            0
# landmark_24_x            0
# landmark_24_y            0
# landmark_24_z            0
# landmark_25_x            0
# landmark_25_y            0
# landmark_25_z            0
# landmark_26_x            0
# landmark_26_y            0
# landmark_26_z            0
# cara_prom_x              0
# cara_prom_y              0
# cara_prom_z              0
# mano_izquierda_prom_x    0
# mano_izquierda_prom_y    0
# mano_izquierda_prom_z    0
# ...

# %%
df_sentarse.isnull().sum()
# Out:
# segundo                   240
# landmark_10_x             240
# landmark_10_y             240
# landmark_10_z             240
# landmark_11_x             240
# landmark_11_y             240
# landmark_11_z             240
# landmark_12_x             240
# landmark_12_y             240
# landmark_12_z             240
# landmark_13_x             240
# landmark_13_y             240
# landmark_13_z             240
# landmark_14_x             240
# landmark_14_y             240
# landmark_14_z             240
# landmark_23_x             240
# landmark_23_y             240
# landmark_23_z             240
# landmark_24_x             240
# landmark_24_y             240
# landmark_24_z             240
# landmark_25_x             240
# landmark_25_y             240
# landmark_25_z             240
# landmark_26_x             240
# landmark_26_y             240
# landmark_26_z             240
# cara_prom_x               240
# cara_prom_y               240
# cara_prom_z               240
# ...

# %%
df_sentarse
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.477394       0.251512      -0.212788       0.524346
# 1       0.07       0.477350       0.251852      -0.215031       0.524356
# 2       0.10       0.477344       0.252125      -0.214477       0.524339
# 3       0.13       0.477233       0.252292      -0.220055       0.524329
# 4       0.17       0.477022       0.252675      -0.233931       0.524318
# ..       ...            ...            ...            ...            ...
# 116      NaN            NaN            NaN            NaN            NaN
# 117      NaN            NaN            NaN            NaN            NaN
# 118      NaN            NaN            NaN            NaN            NaN
# 119      NaN            NaN            NaN            NaN            NaN
# 120      NaN            NaN            NaN            NaN            NaN
#
#      landmark_11_y         landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
# prompt: Necesito borrar la ultima columna de df_sentarse

df_sentarse = df_sentarse.iloc[:, :-1]

# %%
df_sentarse
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.477394       0.251512      -0.212788       0.524346
# 1       0.07       0.477350       0.251852      -0.215031       0.524356
# 2       0.10       0.477344       0.252125      -0.214477       0.524339
# 3       0.13       0.477233       0.252292      -0.220055       0.524329
# 4       0.17       0.477022       0.252675      -0.233931       0.524318
# ..       ...            ...            ...            ...            ...
# 116      NaN            NaN            NaN            NaN            NaN
# 117      NaN            NaN            NaN            NaN            NaN
# 118      NaN            NaN            NaN            NaN            NaN
# 119      NaN            NaN            NaN            NaN            NaN
# 120      NaN            NaN            NaN            NaN            NaN
#
#      landmark_11_y         landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_sentarse.isnull().sum()
# Out:
# segundo                   240
# landmark_10_x             240
# landmark_10_y             240
# landmark_10_z             240
# landmark_11_x             240
# landmark_11_y             240
# landmark_11_z             240
# landmark_12_x             240
# landmark_12_y             240
# landmark_12_z             240
# landmark_13_x             240
# landmark_13_y             240
# landmark_13_z             240
# landmark_14_x             240
# landmark_14_y             240
# landmark_14_z             240
# landmark_23_x             240
# landmark_23_y             240
# landmark_23_z             240
# landmark_24_x             240
# landmark_24_y             240
# landmark_24_z             240
# landmark_25_x             240
# landmark_25_y             240
# landmark_25_z             240
# landmark_26_x             240
# landmark_26_y             240
# landmark_26_z             240
# cara_prom_x               240
# cara_prom_y               240
# cara_prom_z               240
# ...

# %%
df_sentarse.dropna()
# Out:
# Empty DataFrame
# Columns: [segundo, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, cara_prom_x, cara_prom_y, cara_prom_z, mano_izquierda_prom_x, mano_izquierda_prom_y, mano_izquierda_prom_z, mano_derecha_prom_x, mano_derecha_prom_y, mano_derecha_prom_z, pie_izquierdo_prom_x, pie_izquierdo_prom_y, pie_izquierdo_prom_z, pie_derecho_prom_x, pie_derecho_prom_y, pie_derecho_prom_z, Etiqueta, Vista, Unnamed: 43]
# Index: []
#
# [0 rows x 46 columns]

# %%
df_sentarse = df_sentarse.dropna()
df_sentarse
# Out:
# Empty DataFrame
# Columns: [segundo, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, cara_prom_x, cara_prom_y, cara_prom_z, mano_izquierda_prom_x, mano_izquierda_prom_y, mano_izquierda_prom_z, mano_derecha_prom_x, mano_derecha_prom_y, mano_derecha_prom_z, pie_izquierdo_prom_x, pie_izquierdo_prom_y, pie_izquierdo_prom_z, pie_derecho_prom_x, pie_derecho_prom_y, pie_derecho_prom_z, Etiqueta, Vista, Unnamed: 43]
# Index: []
#
# [0 rows x 46 columns]

# %%
df_girar.isnull().sum()
# Out:
# segundo                  0
# landmark_10_x            0
# landmark_10_y            0
# landmark_10_z            0
# landmark_11_x            0
# landmark_11_y            0
# landmark_11_z            0
# landmark_12_x            0
# landmark_12_y            0
# landmark_12_z            0
# landmark_13_x            0
# landmark_13_y            0
# landmark_13_z            0
# landmark_14_x            0
# landmark_14_y            0
# landmark_14_z            0
# landmark_23_x            0
# landmark_23_y            0
# landmark_23_z            0
# landmark_24_x            0
# landmark_24_y            0
# landmark_24_z            0
# landmark_25_x            0
# landmark_25_y            0
# landmark_25_z            0
# landmark_26_x            0
# landmark_26_y            0
# landmark_26_z            0
# cara_prom_x              0
# cara_prom_y              0
# cara_prom_z              0
# mano_izquierda_prom_x    0
# mano_izquierda_prom_y    0
# mano_izquierda_prom_z    0
# ...

# %%
from scipy import stats
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_time_series_with_outliers(df, outliers_mask, columns, title='Time series with outliers'):
    plt.figure(figsize=(14,6))
    for col in columns:
        plt.plot(df.index, df[col], label=col)
        # Marca los outliers en rojo
        plt.scatter(df.index[outliers_mask], df.loc[outliers_mask, col], color='red', s=30)
    plt.legend()
    plt.title(title)
    plt.xlabel('Index / Time')
    plt.ylabel('Value')
    plt.show()

# %%
df = df_agacharse
mask_outliers = (np.abs(stats.zscore(df.select_dtypes(include=[float]), nan_policy='omit')) > 3).any(axis=1)

cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']

plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)

# %%
df = df_caminando
mask_outliers = (np.abs(stats.zscore(df.select_dtypes(include=[float]), nan_policy='omit')) > 3).any(axis=1)

cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']

plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)

# %%
df = df_girar
mask_outliers = (np.abs(stats.zscore(df.select_dtypes(include=[float]), nan_policy='omit')) > 3).any(axis=1)

cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']

plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-1154666412> in <cell line: 0>()
#       4 cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']
#       5
# ----> 6 plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)
#       7
#
# <ipython-input-74-85645404> in plot_time_series_with_outliers(df, outliers_mask, columns, title)
#       5     plt.figure(figsize=(14,6))
#       6     for col in columns:
# ----> 7         plt.plot(df.index, df[col], label=col)
#       8         # Marca los outliers en rojo
#       9         plt.scatter(df.index[outliers_mask], df.loc[outliers_mask, col], color='red', s=30)
#
# ...

# %%
df_sentarse.info()

# %%
# prompt: Convertir los object de df_sentarse a float64, menos etiqueta y vista

import pandas as pd
for col in df_sentarse.columns:
    if df_sentarse[col].dtype == 'object' and col not in ['Etiqueta', 'Vista']:
        df_sentarse[col] = pd.to_numeric(df_sentarse[col], errors='coerce')

df_sentarse.info()

# %%
# prompt: Borrar la ultima columna de df_sentarse

df_sentarse = df_sentarse.iloc[:, :-1]

# %%
df_sentarse

# %%
df_sentarse.dropna()

# %%
# prompt: Convertir los object de df_sentarse a float64, menos etiqueta y vista

import pandas as pd
for col in df_sentarse.columns:
    if df_sentarse[col].dtype == 'object' and col not in ['Etiqueta', 'Vista']:
        df_sentarse[col] = pd.to_numeric(df_sentarse[col], errors='coerce')

df_sentarse.info()

# %%
# prompt: Guardar df_sentarse en /content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos

df_sentarse.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_sentarse.csv', index=False)

# %%
df = df_sentarse
mask_outliers = (np.abs(stats.zscore(df.select_dtypes(include=[float]), nan_policy='omit')) > 3).any(axis=1)

cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']

plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)

# %%
df_girar.info()

# %%
# prompt: # prompt: Convertir los object de df_girar a float64, menos etiqueta y vista

import pandas as pd
for col in df_girar.columns:
    if df_girar[col].dtype == 'object' and col not in ['Etiqueta', 'Vista']:
        df_girar[col] = pd.to_numeric(df_girar[col], errors='coerce')

df_girar.info()

# %%
df_girar.isnull().sum()

# %%
df_girar.dropna()

# %%
df = df_girar
mask_outliers = (np.abs(stats.zscore(df.select_dtypes(include=[float]), nan_policy='omit')) > 3).any(axis=1)

cols_to_plot = ['landmark_11_x','landmark_11_z','landmark_12_z','landmark_12_x', 'landmark_23_y', 'landmark_24_y','cara_prom_x','cara_prom_y','cara_prom_z','mano_izquierda_prom_x','mano_derecha_prom_x']

plot_time_series_with_outliers(df, mask_outliers, cols_to_plot)

# %%
# prompt: Guardar df_sentarse en /content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos

df_girar.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_girar.csv', index=False)

# %%
df_agacharse.isnull().sum()

# %%
# prompt: Guardar df_sentarse en /content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos

df_agacharse.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_agacharse.csv', index=False)

# %%
df_caminando.isnull().sum()

# %%
df_reversa.isnull().sum()

# %%
df_reversa.info()

# %%
# prompt: # prompt: Convertir los object de df_reversa a float64, menos etiqueta y vista

import pandas as pd
for col in df_reversa.columns:
    if df_reversa[col].dtype == 'object' and col not in ['Etiqueta', 'Vista']:
        df_reversa[col] = pd.to_numeric(df_reversa[col], errors='coerce')

df_reversa.info()

# %%
df_reversa.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_reversa.csv', index=False)

# %%
df_caminando.info()

# %%
# prompt: # prompt: Convertir los object de df_caminando a float64, menos etiqueta y vista

import pandas as pd
for col in df_caminando.columns:
    if df_caminando[col].dtype == 'object' and col not in ['Etiqueta', 'Vista']:
        df_caminando[col] = pd.to_numeric(df_caminando[col], errors='coerce')

df_caminando.info()

# %%
df_caminando.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_caminando.csv', index=False)

# %%
df_caminando.info()

# %%
df_unido = pd.concat([df_agacharse, df_caminando, df_girar, df_reversa, df_sentarse], ignore_index=True)

# %%
df_unido.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_unido.csv', index=False)

# %%
df_agacharseS = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseS1.csv',delimiter=';')
df_agacharseS
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.542490       0.300761      -0.193365       0.591025
# 1       0.07       0.543713       0.298910      -0.196680       0.591183
# 2       0.10       0.544616       0.297563      -0.194695       0.591195
# 3       0.13       0.545201       0.297177      -0.184458       0.591236
# 4       0.17       0.545585       0.297058      -0.190356       0.591316
# ..       ...            ...            ...            ...            ...
# 282     9.46       0.527222       0.303112      -0.166456       0.574441
# 283     9.49       0.527327       0.303527      -0.168977       0.574214
# 284     9.53       0.527318       0.303595      -0.172742       0.573936
# 285     9.56       0.527245       0.303585      -0.182298       0.573670
# 286     9.60       0.527137       0.303556      -0.188911       0.573484
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_caminarS1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS1.csv',delimiter=';')
df_caminarS1
# Out:
#      segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0       0.03       0.535932       0.182026      -0.199147       0.572615
# 1       0.07       0.536286       0.182021      -0.190995       0.572557
# 2       0.10       0.536409       0.182008      -0.185068       0.572413
# 3       0.13       0.536448       0.181996      -0.184508       0.572381
# 4       0.17       0.536587       0.182001      -0.186885       0.572314
# ..       ...            ...            ...            ...            ...
# 151     5.07       0.561645       0.146016      -0.330465       0.618403
# 152     5.10       0.561813       0.146825      -0.320751       0.618604
# 153     5.13       0.561997       0.147450      -0.316456       0.618885
# 154     5.17       0.562080       0.147755      -0.311024       0.619116
# 155     5.20       0.562164       0.148099      -0.308734       0.619435
#
#      landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  \
# ...

# %%
df_caminandoS2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS2.csv',delimiter=';')
df_girandoS1_BA = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosAbiertosS1.csv',delimiter=';')
df_girandoS2_BA = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de girandoBrazosAbiertosS2.csv',delimiter=';')
df_agacharseS1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseS1.csv',delimiter=';')
df_agacharseS1_lateral = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de agacharseLadoS1.csv',delimiter=';')
df_caminandoS1 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS1.csv',delimiter=';')
df_caminandoS2 = pd.read_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosEtiq/Copia de caminandoS2.csv',delimiter=';')

# %%
df_caminandoS2.head()
# Out:
#    segundo  landmark_10_x  landmark_10_y  landmark_10_z  landmark_11_x  \
# 0     0.03       0.572155       0.293388      -0.196815       0.607396
# 1     0.07       0.572540       0.291932      -0.184707       0.607223
# 2     0.10       0.572872       0.291382      -0.183163       0.607185
# 3     0.13       0.573183       0.290920      -0.178856       0.607200
# 4     0.17       0.573286       0.290875      -0.182488       0.607214
#
#    landmark_11_y  landmark_11_z  landmark_12_x  landmark_12_y  landmark_12_z  \
# 0       0.338900      -0.082125       0.549111       0.340296      -0.088017
# 1       0.338831      -0.070735       0.549103       0.340317      -0.081993
# 2       0.338835      -0.067778       0.549077       0.340382      -0.079922
# 3       0.338795      -0.064570       0.549103       0.340382      -0.076426
# 4       0.338785      -0.067718       0.549133       0.340341      -0.078263
#
#    ...  mano_derecha_prom_z  pie_izquierdo_prom_x  pie_izquierdo_prom_y  \
# ...

# %%
df_samu = pd.concat([df_caminandoS2,df_girandoS1_BA, df_girandoS2_BA, df_caminandoS1, df_caminandoS2])

# %%
df_samu.to_csv('/content/drive/MyDrive/Inteligencia artificial/ProyectoIA/nuevo/data/datosUnidos/df_samu.csv', index=False)
